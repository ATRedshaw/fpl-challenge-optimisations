# %%
# Relevant module imports and installs
import pandas as pd
# !pip install pulp brotli fuzzywuzzy
import pulp as plp
import sys 
import os
from collections import defaultdict
from fuzzywuzzy import process
# Out:
# Requirement already satisfied: pulp in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.9.0)
# Requirement already satisfied: brotli in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: fuzzywuzzy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.18.0)
#
# [notice] A new release of pip is available: 23.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Get the absolute path to the directory containing the Python file
module_path = os.path.abspath(os.path.join('..', '..'))

# Add the directory to sys.path
if module_path not in sys.path:
    sys.path.append(module_path)

# Now you can import the module
from projections import generate_projections, generate_stat_projections, append_stat_projections

point_projections = generate_projections()
stat_projections = generate_stat_projections()

projections_data = append_stat_projections(point_projections, stat_projections, 2)

# %%
def fuzzy_ban_players(df, ban_ids):
    while True:
        search_name = input("Enter player name to ban (or press enter to finish): ").strip()
        
        if search_name.lower() == '':
            break
        
        # Perform fuzzy matching with a lower score cutoff and no limit
        matches = process.extractBests(search_name, df['Name'].tolist(), score_cutoff=50, limit=10)
        
        if not matches:
            print("No matches found. Please try again.")
            continue
        
        # Display matches
        print("Matches found:")
        for idx, (name, score) in enumerate(matches, 1):
            player_index = df[df['Name'] == name].index[0]
            player_id = df.loc[player_index, 'ID']
            print(f"{idx}. {name} (ID: {player_id}, Index: {player_index}, Score: {score})")
        
        # Ask user to select a match
        while True:
            choice = input("Enter the number of the player to ban (or 'skip' to search again): ")
            if choice.lower() == 'skip':
                break
            try:
                choice_idx = int(choice) - 1
                if 0 <= choice_idx < len(matches):
                    selected_name = matches[choice_idx][0]
                    selected_index = df[df['Name'] == selected_name].index[0]
                    selected_id = df.loc[selected_index, 'ID']
                    ban_ids.append(selected_index)
                    print(f"Banned: {selected_name} (ID: {selected_id}, Index: {selected_index})")
                    break
                else:
                    print("Invalid choice. Please try again.")
            except ValueError:
                print("Invalid input. Please enter a number or 'skip'.")
    
    return ban_ids

ban_ids = []
ban_ids = fuzzy_ban_players(projections_data, ban_ids)
print("Final ban list (indices):", ban_ids)
# Out:
# Final ban list (indices): []

# %% [markdown]
# # 2024/25 GW2 Challenge: All Out Attack - Goals are worth double points. Your squad may only contain 1 Goalkeeper and 4 Forwards.

# %% [markdown]
# ### Points Refinement

# %%
# Refine points values based on scoring probabilities
# Function to calculate the adjusted points for Forwards
def adjust_forward_points(row):
    if row['Position'] == 'Forward':
        # Assume that a goal is worth 4 points in the original prediction
        estimated_goal_points = row['Score'] * 4
        
        # Remove the original goal points from the prediction
        non_goal_points = row['Predicted_Points'] - estimated_goal_points
        
        # Double the goal points
        doubled_goal_points = estimated_goal_points * 2
        
        # Return the adjusted total
        return non_goal_points + doubled_goal_points
    else:
        # For non-Forwards, return the original prediction
        return row['Predicted_Points']

# Apply the adjustment to the dataframe
projections_data['Adjusted_Points'] = projections_data.apply(adjust_forward_points, axis=1)

# Round the adjusted points to 2 decimal places
projections_data['Adjusted_Points'] = projections_data['Adjusted_Points'].round(2)
projections_data['Predicted_Points'] = projections_data['Adjusted_Points']

# %% [markdown]
# ### Optimisation

# %%
# Get the number of players and their list of ids
player_ids = projections_data['ID'].tolist()
player_count = len(player_ids)

# Set up the problem
model = plp.LpProblem("fpl-gw1-challenge", plp.LpMaximize)

# Define the decision variables
lineup = [
    plp.LpVariable(f"lineup_{i}", lowBound=0, upBound=1, cat="Integer")
    for i in player_ids
]

# Define captain variables
captain = [
    plp.LpVariable(f"captain_{i}", lowBound=0, upBound=1, cat="Integer")
    for i in player_ids
]

# Set the objective function (the number of points scored by the team, with captain's points doubled)
model += plp.lpSum([lineup[i] * projections_data.loc[i, 'Predicted_Points'] for i in range(player_count)]) + \
         plp.lpSum([captain[i] * projections_data.loc[i, 'Predicted_Points'] for i in range(player_count)])

# Constraints

# Total number of players = 5 (1 goalkeeper + 4 forwards)
model += plp.lpSum(lineup) == 5

# List players by index to be EXCLUDED from the lineup
for id in ban_ids:
    model += lineup[id] == 0

# Exactly one captain
model += plp.lpSum(captain) == 1

# Captain must be in the lineup
for i in range(player_count):
    model += captain[i] <= lineup[i]

# Exactly 1 Goalkeeper
model += plp.lpSum([lineup[i] for i in range(player_count) if projections_data.loc[i, 'Position'] == 'Goalkeeper']) == 1

# Exactly 4 Forwards
model += plp.lpSum([lineup[i] for i in range(player_count) if projections_data.loc[i, 'Position'] == 'Forward']) == 4

# Budget constraint: Total cost must be less than or equal to 35m
model += plp.lpSum([lineup[i] * projections_data.loc[i, 'Cost'] for i in range(player_count)]) <= 35

# Solve the problem
model.solve()

# Function to print players by position
def print_players_by_position(players_dict):
    total_points = 0
    total_cost = 0
    for position in ['Goalkeeper', 'Forward']:
        if position in players_dict:
            print(f"\n{position}:")
            for player in players_dict[position]:
                captain_str = " (C)" if player['Captain'] else ""
                points = player['Predicted_Points'] * (2 if player['Captain'] else 1)
                print(f"  {player['Name']}{captain_str} - {player['Team']} - Cost: {player['Cost']}m - Predicted Points: {points}")
                total_points += points
                total_cost += player['Cost']
    print(f"\nTotal Predicted Points: {round(total_points, 2)}")
    print(f"Total Cost: {round(total_cost, 2)}m")

# Print the results
print("Status:", plp.LpStatus[model.status])
selected_players = defaultdict(list)
for i in range(player_count):
    if lineup[i].value() == 1:
        player = projections_data.loc[i]
        selected_players[player['Position']].append({
            'Name': player['Name'],
            'Team': player['Team'],
            'Cost': player['Cost'],
            'Predicted_Points': player['Predicted_Points'],
            'Captain': captain[i].value() == 1
        })

print_solution = False
if print_solution:
    print("\nOptimal Lineup:")
    print_players_by_position(selected_players)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/91/3jnk9jzn3kx1mwsfzhddwbww0000gn/T/5bfbf99aa5c64adebd87aa88654ed279-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/91/3jnk9jzn3kx1mwsfzhddwbww0000gn/T/5bfbf99aa5c64adebd87aa88654ed279-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 318 COLUMNS
# At line 3663 RHS
# At line 3977 BOUNDS
# At line 4594 ENDATA
# Problem MODEL has 313 rows, 616 columns and 1626 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 41.2757 - 0.00 seconds
# Cgl0004I processed model has 313 rows, 616 columns (616 integer (616 of which binary)) and 1626 elements
# Cutoff increment increased from 1e-05 to 0.00999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.984615
# Cbc0038I Pass   1: suminf.    0.60952 (4) obj. -39.784 iterations 25
# Cbc0038I Solution found of -20.56
# Cbc0038I Before mini branch and bound, 610 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 313 rows 616 columns, reduced to 5 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -20.56 to -35.26 (0.02 seconds)
# Cbc0038I Round again with cutoff of -35.8706
# Cbc0038I Reduced cost fixing fixed 148 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.60952 (4) obj. -40.3615 iterations 38
# Cbc0038I Pass   3: suminf.    0.81034 (4) obj. -35.8706 iterations 56
# Cbc0038I Pass   4: suminf.    0.68538 (4) obj. -35.8706 iterations 8
# Cbc0038I Pass   5: suminf.    0.67368 (4) obj. -39.8104 iterations 51
# Cbc0038I Pass   6: suminf.    0.60952 (4) obj. -39.1315 iterations 4
# Cbc0038I Pass   7: suminf.    1.13617 (4) obj. -35.8706 iterations 49
# Cbc0038I Pass   8: suminf.    0.95633 (4) obj. -35.8706 iterations 5
# Cbc0038I Pass   9: suminf.    0.50580 (4) obj. -35.8706 iterations 21
# Cbc0038I Pass  10: suminf.    0.33566 (3) obj. -35.8706 iterations 10
# Cbc0038I Pass  11: suminf.    0.64672 (2) obj. -35.8706 iterations 5
# Cbc0038I Pass  12: suminf.    0.30476 (2) obj. -36.322 iterations 27
# Cbc0038I Pass  13: suminf.    0.38438 (2) obj. -35.8706 iterations 64
# Cbc0038I Pass  14: suminf.    1.59469 (5) obj. -35.8706 iterations 61
# Cbc0038I Pass  15: suminf.    0.95238 (4) obj. -37.8124 iterations 151
# Cbc0038I Pass  16: suminf.    1.46677 (4) obj. -35.8706 iterations 45
# Cbc0038I Pass  17: suminf.    1.20889 (5) obj. -35.8706 iterations 28
# Cbc0038I Pass  18: suminf.    1.14286 (5) obj. -35.8706 iterations 65
# Cbc0038I Pass  19: suminf.    1.15068 (4) obj. -35.8706 iterations 50
# Cbc0038I Pass  20: suminf.    1.45083 (5) obj. -35.8706 iterations 57
# Cbc0038I Pass  21: suminf.    1.45083 (5) obj. -35.8706 iterations 6
# Cbc0038I Pass  22: suminf.    0.45714 (5) obj. -35.8706 iterations 50
# Cbc0038I Pass  23: suminf.    0.45714 (5) obj. -35.8706 iterations 0
# Cbc0038I Pass  24: suminf.    0.81890 (4) obj. -35.8706 iterations 39
# Cbc0038I Pass  25: suminf.    0.45714 (4) obj. -37.2366 iterations 41
# Cbc0038I Pass  26: suminf.    0.81709 (4) obj. -35.8706 iterations 39
# Cbc0038I Pass  27: suminf.    1.71653 (5) obj. -35.8706 iterations 56
# Cbc0038I Pass  28: suminf.    0.69474 (2) obj. -35.874 iterations 51
# Cbc0038I Pass  29: suminf.    0.69349 (2) obj. -35.8706 iterations 32
# Cbc0038I Pass  30: suminf.    0.69672 (3) obj. -35.8706 iterations 11
# Cbc0038I Pass  31: suminf.    0.55160 (4) obj. -35.8706 iterations 25
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 585 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 313 rows 616 columns, reduced to 15 rows 31 columns
# Cbc0038I Mini branch and bound improved solution from -35.26 to -38.51 (0.05 seconds)
# Cbc0038I Round again with cutoff of -39.0711
# Cbc0038I Reduced cost fixing fixed 444 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.60952 (4) obj. -40.9375 iterations 11
# Cbc0038I Pass  32: suminf.    1.28077 (4) obj. -39.0711 iterations 62
# Cbc0038I Pass  33: suminf.    1.16778 (4) obj. -39.0711 iterations 6
# Cbc0038I Pass  34: suminf.    0.67368 (4) obj. -40.2079 iterations 28
# Cbc0038I Pass  35: suminf.    0.60952 (4) obj. -39.7075 iterations 6
# Cbc0038I Pass  36: suminf.    0.85476 (4) obj. -39.0711 iterations 25
# Cbc0038I Pass  37: suminf.    1.46377 (5) obj. -39.0711 iterations 7
# Cbc0038I Pass  38: suminf.    0.60952 (4) obj. -40.9375 iterations 26
# Cbc0038I Pass  39: suminf.    0.60952 (4) obj. -40.9375 iterations 0
# Cbc0038I Pass  40: suminf.    1.28077 (4) obj. -39.0711 iterations 24
# Cbc0038I Pass  41: suminf.    1.16778 (4) obj. -39.0711 iterations 6
# Cbc0038I Pass  42: suminf.    0.67368 (4) obj. -40.2079 iterations 24
# Cbc0038I Pass  43: suminf.    0.60952 (4) obj. -39.7075 iterations 5
# Cbc0038I Pass  44: suminf.    0.85476 (4) obj. -39.0711 iterations 25
# Cbc0038I Pass  45: suminf.    1.49365 (5) obj. -39.0711 iterations 20
# Cbc0038I Pass  46: suminf.    1.17128 (4) obj. -39.0711 iterations 7
# Cbc0038I Pass  47: suminf.    1.10327 (4) obj. -39.0711 iterations 4
# Cbc0038I Pass  48: suminf.    1.10327 (4) obj. -39.0711 iterations 2
# Cbc0038I Pass  49: suminf.    1.75238 (4) obj. -39.3004 iterations 30
# Cbc0038I Pass  50: suminf.    1.84072 (4) obj. -39.0711 iterations 25
# Cbc0038I Pass  51: suminf.    2.52192 (6) obj. -39.0711 iterations 9
# Cbc0038I Pass  52: suminf.    1.53402 (4) obj. -39.0711 iterations 9
# Cbc0038I Pass  53: suminf.    0.81885 (4) obj. -39.0711 iterations 4
# Cbc0038I Pass  54: suminf.    0.81885 (4) obj. -39.0711 iterations 2
# Cbc0038I Pass  55: suminf.    1.93333 (5) obj. -39.0711 iterations 12
# Cbc0038I Pass  56: suminf.    1.80047 (4) obj. -39.0711 iterations 7
# Cbc0038I Pass  57: suminf.    1.75128 (4) obj. -39.0711 iterations 2
# Cbc0038I Pass  58: suminf.    1.92042 (5) obj. -39.0711 iterations 4
# Cbc0038I Pass  59: suminf.    1.75128 (4) obj. -39.0711 iterations 4
# Cbc0038I Pass  60: suminf.    1.38180 (4) obj. -39.0711 iterations 8
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 599 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 313 rows 616 columns, reduced to 7 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -38.51 - took 0.06 seconds
# Cbc0012I Integer solution of -38.51 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 313 rows 616 columns, reduced to 4 rows 4 columns
# Cbc0013I At root node, 0 cuts changed objective from -41.275692 to -41.275692 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 38 column cuts (38 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -38.51, took 8 iterations and 0 nodes (0.08 seconds)
# Cbc0032I Strong branching done 4 times (29 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 386 variables fixed on reduced cost
# Cuts at root node changed objective from -41.2757 to -33
# Probing was tried 1 times and created 38 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                38.51000000
# Enumerated nodes:               0
# Total iterations:               8
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.08   (Wallclock seconds):       0.09
#
# Status: Optimal
